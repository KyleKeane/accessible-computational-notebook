# %% [markdown]
# # Rich outputs and image descriptions
#
# This notebook shows how outputs from other tools (like Jupyter with
# matplotlib or pandas) appear here, and how the **image description flow**
# works. Navigate to each cell and press **Ctrl+Shift+O** to read its output.

# %% [markdown]
# ## An image with a description
#
# This image was described with **Ctrl+Shift+G**. A screen reader announces the description instead of silence.

# %%
# (output produced elsewhere, e.g. matplotlib)
plot_sales()

# %% [markdown]
# ## An image without one (yet)
#
# Select the cell below and press **Ctrl+Shift+G** to add a description. It is saved into this file for every future reader.

# %%
plot_costs()

# %% [markdown]
# ## A table
#
# HTML tables (like pandas DataFrames) render as real tables, so screen readers can navigate by row and column.

# %%
df.head(3)
# Out:
#    month  sales
# 0    Jan     10
# 1    Feb     14
# 2    Mar      9
