# %% [markdown]
# # Getting started
#
# Welcome! This notebook walks through the basics. Press **Shift+Enter** to run
# a cell and move to the next one. Press **F1** any time for the shortcut list,
# or **Alt** to explore the menus — every command is there.

# %%
message = "Hello from a persistent kernel"
print(message)

# %%
# Variables persist between cells: this uses message from above.
len(message)

# %% [markdown]
# ## Errors are fine
#
# The next cell raises an error on purpose. The error is announced, and the
# session survives — run the cell after it to check.

# %%
1 / 0  # ZeroDivisionError, announced assertively

# %%
print("Still alive:", message)

# %% [markdown]
# ## Useful commands
#
# - **Ctrl+Shift+I** describes the current cell
# - **Ctrl+Shift+O** reads the current cell output
# - **Ctrl+Shift+K** announces kernel status
# - **Ctrl+S** saves this notebook as standard .ipynb — it opens in Jupyter too
